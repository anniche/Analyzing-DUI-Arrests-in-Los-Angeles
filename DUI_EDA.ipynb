# %%
import pandas as pd
import numpy as np
import urllib
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
#import seaborn as sns

import geopandas as gpd
import shapely as shp
from shapely.geometry import Point, Polygon

# %matplotlib inline

url = "Arrest_Data_from_2010_to_2019.csv"
arrest_data = pd.read_csv(url)

# %%
pd.set_option('display.max_columns', None)
arrest_data.head()
# Out:
#    Report ID Report Type Arrest Date    Time  Area ID  Area Name  \
# 0    2377805     BOOKING  06/22/2010  1845.0       16   Foothill
# 1  121920046         RFC  09/28/2012   930.0       19    Mission
# 2  101820989         RFC  10/20/2010   700.0       18  Southeast
# 3   90712341         RFC  03/10/2011   940.0        7   Wilshire
# 4  121909585         RFC  04/01/2012  1715.0       19    Mission
#
#    Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 0                1664   46        F            W                6.0
# 1                1998   60        M            H                NaN
# 2                1829   14        M            H                8.0
# 3                 776   45        M            B               18.0
# 4                1993   37        M            H                NaN
#
#   Charge Group Description Arrest Type Code      Charge  \
# 0                  Larceny                F    487(A)PC
# 1                      NaN                M  25620(A)BP
# 2           Other Assaults                M       242PC
# 3               Drunkeness                M  41.27CLAMC
# 4                      NaN                M  25620(A)BP
#
#                   Charge Description      Disposition Description  \
# 0  GRAND THEFT MONEY/PROPERTY > $400  MISDEMEANOR COMPLAINT FILED
# 1                                NaN  MISDEMEANOR COMPLAINT FILED
# 2                            BATTERY                          NaN
# 3                 DRINKING IN PUBLIC  MISDEMEANOR COMPLAINT FILED
# 4                                NaN  MISDEMEANOR COMPLAINT FILED
#
#                                    Address Cross Street      LAT       LON  \
# 0                                PENDLETON     GLENOAKS  34.2375 -118.3745
# 1  7600    WOODMAN                      AV          NaN  34.2111 -118.4309
# 2  7200    QUAIL                        DR          NaN  34.1025 -118.2091
# 3  4500 W  WASHINGTON                   BL          NaN  34.0399 -118.3375
# 4  8100    SEPULVEDA                    PL          NaN  34.2208 -118.4662
#
#                     Location            Booking Date  Booking Time  \
# 0  POINT (-118.3745 34.2375)  06/22/2010 12:00:00 AM        2108.0
# 1  POINT (-118.4309 34.2111)                     NaN           NaN
# 2  POINT (-118.2091 34.1025)                     NaN           NaN
# 3  POINT (-118.3375 34.0399)                     NaN           NaN
# 4  POINT (-118.4662 34.2208)                     NaN           NaN
#
#     Booking Location  Booking Location Code
# 0  VALLEY - JAIL DIV                 4279.0
# 1                NaN                    NaN
# 2                NaN                    NaN
# 3                NaN                    NaN
# 4                NaN                    NaN

# %%
arrest_data.columns
# Out:
# Index(['Report ID', 'Report Type', 'Arrest Date', 'Time', 'Area ID',
#        'Area Name', 'Reporting District', 'Age', 'Sex Code', 'Descent Code',
#        'Charge Group Code', 'Charge Group Description', 'Arrest Type Code',
#        'Charge', 'Charge Description', 'Disposition Description', 'Address',
#        'Cross Street', 'LAT', 'LON', 'Location', 'Booking Date',
#        'Booking Time', 'Booking Location', 'Booking Location Code'],
#       dtype='object')

# %%
arrest_data["Charge Group Description"].unique()
# Out:
# array(['Larceny', nan, 'Other Assaults', 'Drunkeness',
#        'Prostitution/Allied', 'Miscellaneous Other Violations',
#        'Disturbing the Peace', 'Weapon (carry/poss)', 'Liquor Laws',
#        'Gambling', 'Aggravated Assault', 'Narcotic Drug Laws',
#        'Disorderly Conduct', 'Pre-Delinquency', 'Sex (except rape/prst)',
#        'Burglary', 'Fraud/Embezzlement', 'Driving Under Influence',
#        'Robbery', 'Moving Traffic Violations', 'Receive Stolen Property',
#        'Vehicle Theft', 'Rape', 'Against Family/Child',
#        'Forgery/Counterfeit', 'Non-Criminal Detention', 'Homicide',
#        'Federal Offenses'], dtype=object)

# %%
#Type of Crime Distribution
arrest_data["Charge Group Description"].value_counts()

#DUI is a one of the most common crimes
# Out:
# Miscellaneous Other Violations    247309
# Narcotic Drug Laws                164935
# Driving Under Influence           121528
# Drunkeness                        116190
# Aggravated Assault                 86713
# Larceny                            70049
# Other Assaults                     63570
# Moving Traffic Violations          53681
# Liquor Laws                        52483
# Prostitution/Allied                40801
# Disorderly Conduct                 37387
# Weapon (carry/poss)                31228
# Robbery                            26649
# Vehicle Theft                      25274
# Burglary                           24388
# Sex (except rape/prst)             13429
# Pre-Delinquency                    11897
# Fraud/Embezzlement                 11443
# Against Family/Child                7457
# Forgery/Counterfeit                 6996
# Non-Criminal Detention              6908
# Receive Stolen Property             6726
# Disturbing the Peace                3149
# Rape                                3002
# Gambling                            2501
# Homicide                            2474
# Federal Offenses                     248
# Name: Charge Group Description, dtype: int64

# %%
#Extract relevant numeric and categorical features in separate dataframes

# %%
#filter to only DUI crimes
#create a mask --> where CGD == "Driving Under Influence", extract driving under influence data 
dui_data = arrest_data[arrest_data["Charge Group Description"] == "Driving Under Influence"]

# %%
#how much data after filtering
dui_data.shape 

#(121528, 25)
#array has two dimensions: 121528 entries and 25 columns
# Out:
# (121528, 25)

# %%
dui_data
# Out:
#          Report ID Report Type Arrest Date    Time  Area ID    Area Name  \
# 948      150326444         RFC  12/12/2015  2000.0        3    Southwest
# 973      151817927         RFC  09/25/2015  2020.0       18    Southeast
# 1131     162106165         RFC  02/19/2016  2220.0       21      Topanga
# 4297     100601250         RFC  11/01/2010   215.0        6    Hollywood
# 4307     100601358         RFC  12/18/2010   140.0        6    Hollywood
# ...            ...         ...         ...     ...      ...          ...
# 1320924    5765337     BOOKING  10/05/2019   212.0        1      Central
# 1320951    5810338     BOOKING  11/28/2019  1915.0       18    Southeast
# 1320959    5822397     BOOKING  12/14/2019   302.0       15  N Hollywood
# 1321067    3755468     BOOKING  10/26/2013  2155.0        6    Hollywood
# 1321124    3457315     BOOKING  02/09/2013   244.0       10  West Valley
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 948                     361   19        M            B               22.0
# 973                    1801   41        F            B               22.0
# 1131                   2105   40        M            W               22.0
# 4297                    636   22        F            O               22.0
# 4307                    645   26        M            W               22.0
# ...                     ...  ...      ...          ...                ...
# 1320924                 119   22        M            H               22.0
# 1320951                1834   45        F            B               22.0
# 1320959                1566   28        M            W               22.0
# 1321067                 647   22        M            B               22.0
# 1321124                1044   38        M            C               22.0
#
#         Charge Group Description Arrest Type Code      Charge  \
# 948      Driving Under Influence                M  23152(E)VC
# 973      Driving Under Influence                M  23152(E)VC
# 1131     Driving Under Influence                M  23152(E)VC
# 4297     Driving Under Influence                M  23152(A)VC
# 4307     Driving Under Influence                M  23152(A)VC
# ...                          ...              ...         ...
# 1320924  Driving Under Influence                M  23152(A)VC
# 1320951  Driving Under Influence                M  23152(A)VC
# 1320959  Driving Under Influence                M  23152(A)VC
# 1321067  Driving Under Influence                M  23152(A)VC
# 1321124  Driving Under Influence                M  23152(A)VC
#
#                         Charge Description        Disposition Description  \
# 948      DUI .04 OR MORE BAC PASS FOR HIRE    MISDEMEANOR COMPLAINT FILED
# 973      DUI .04 OR MORE BAC PASS FOR HIRE    MISDEMEANOR COMPLAINT FILED
# 1131     DUI .04 OR MORE BAC PASS FOR HIRE    MISDEMEANOR COMPLAINT FILED
# 4297           DRUNK DRIVING ALCOHOL/DRUGS    MISDEMEANOR COMPLAINT FILED
# 4307           DRUNK DRIVING ALCOHOL/DRUGS    MISDEMEANOR COMPLAINT FILED
# ...                                    ...                            ...
# 1320924        DRUNK DRIVING ALCOHOL/DRUGS                            NaN
# 1320951        DRUNK DRIVING ALCOHOL/DRUGS    MISDEMEANOR COMPLAINT FILED
# 1320959        DRUNK DRIVING ALCOHOL/DRUGS                            NaN
# 1321067        DRUNK DRIVING ALCOHOL/DRUGS         FELONY COMPLAINT FILED
# 1321124        DRUNK DRIVING ALCOHOL/DRUGS  849(B)(1) PC/TECHNICAL ARREST
#
#                                  Address                     Cross Street  \
# 948                              LA BREA                            RODEO
# 973                           MANCHESTER                           HOOVER
# 1131     CANOGA                       AV  CHASE                        ST
# 4297     CAHUENGA                     BL  HOLLYWOOD                    BL
# 4307     HOLLYWOOD                    BL  HIGHLAND                     AV
# ...                                  ...                              ...
# 1320924                        RIVERSIDE                             EADS
# 1320951                            108TH                            TOWNE
# 1320959                        RIVERSIDE                         VINELAND
# 1321067                        HOLLYWOOD                           ARGYLE
# 1321124  RESEDA                       BL  VENTURA                      FY
#
#              LAT       LON                   Location            Booking Date  \
# 948      34.0183 -118.3556  POINT (-118.3556 34.0183)                     NaN
# 973      33.9601 -118.2881  POINT (-118.2881 33.9601)                     NaN
# 1131     34.2246 -118.5976  POINT (-118.5976 34.2246)                     NaN
# 4297     34.1016 -118.3297  POINT (-118.3297 34.1016)                     NaN
# 4307     34.1016 -118.3387  POINT (-118.3387 34.1016)                     NaN
# ...          ...       ...                        ...                     ...
# 1320924  34.0577 -118.2318  POINT (-118.2318 34.0577)  10/05/2019 12:00:00 AM
# 1320951  33.9398 -118.2611  POINT (-118.2611 33.9398)  11/28/2019 12:00:00 AM
# 1320959  34.1524 -118.3703  POINT (-118.3703 34.1524)  12/14/2019 12:00:00 AM
# 1321067  34.1016 -118.3252  POINT (-118.3252 34.1016)  10/27/2013 12:00:00 AM
# 1321124  34.1765 -118.5333  POINT (-118.5333 34.1765)  02/09/2013 12:00:00 AM
#
#          Booking Time   Booking Location  Booking Location Code
# 948               NaN                NaN                    NaN
# 973               NaN                NaN                    NaN
# 1131              NaN                NaN                    NaN
# 4297              NaN                NaN                    NaN
# 4307              NaN                NaN                    NaN
# ...               ...                ...                    ...
# 1320924         351.0            77TH ST                 4212.0
# 1320951        2122.0            77TH ST                 4212.0
# 1320959         428.0  VALLEY - JAIL DIV                 4279.0
# 1321067           4.0          HOLLYWOOD                 4206.0
# 1321124         353.0  VALLEY - JAIL DIV                 4279.0
#
# [121528 rows x 25 columns]

# %%
#1) Data Cleaning 

def clean_data(orig_df): 
    
  #make a copy of original dui data 
    df = orig_df.copy()
    
  #extract rows where report ID is not NaN
    df = df[df["Report ID"].notna()]
    
 #drop duplicate rows 
    df = df.drop_duplicates()
    
 #add more to clean_data() as needed when doing EDA
    
    return df

# %%
dui_datac = clean_data(dui_data)
arrest_datac = clean_data(arrest_data)

# %%
#Unique charge descriptions for Driving Under Influence Arrests
dui_datac["Charge Description"].unique()
# Out:
# array(['DUI .04 OR MORE BAC PASS FOR HIRE', 'DRUNK DRIVING ALCOHOL/DRUGS',
#        'DUI ALCOHOL CAUSING INJURY', 'DRUNK DRIVING .10 OR ABOVE',
#        'DUI ALCOHOL/DRUGS ON BICYCLE', 'DUI OF ANY DRUG',
#        'UNDER 21 DRIVING VEH W/BLOOD ALCOHOL .01+',
#        'DUI OF COMBINED DRUG & ALCOHOL INFLUENCE',
#        'DRUNK DRIVING ADDICT DRIVE VEHICLE', 'DUI ALCOHOL/DRUG W/PRIORS',
#        'DUI WITH PRIOR CONVITIONS', 'DUI ALCOHOL/0.08 W/PRS',
#        'DUI .08 ALCOHOL CAUSING INJURY', 'FELONY FOR FOURTH DUI',
#        'DUI W/PRIOR SPEC CONVICTIONS',
#        'MINOR DRIVE W/BLOOD ALCOHOL OF 0.05%+',
#        'DRIVING COMMERCIAL VEH W/.04 BLOOD/ALCOHL', 'DRUNK DRIVING',
#        'OPERATE MOTOR SCOOTR WHILE UNDER INFLUENC', 'DUI DRUGS',
#        'DUI/BOAT OR WATERCRAFT', 'DUI OF A DRUG CAUSING INJURY',
#        'DUI W/PRIOR SEPC CONVICTIONS', 'DUI W/PRIOR SPECIFIC CONVICTIONS',
#        'DUI WITH PRIOR CONVICTIONS',
#        'DUI OF ALCOHOL & DRUG CAUSING INJURY', 'ATTEMPT DRUNK DRIVING'],
#       dtype=object)

# %%
#Univariate Analysis -- distribution of types of DUI arrests or overall crime data

# %%
#Bi-Variate Analysis

# %%
#arrest_datac["Charge Description"]
#selects each charge description entry (each row)

# %%
#split data by area name (each dataframe corresponding to an area name)
#select charge description column and display # of unique charge description values for the area name
#divide by #arrest_datac.shape[0] which gives you total number of rows (arrests) in the area (--> actually gives total # of rows of cleaned arrest data set)
#multiply by 100 to get the proportions

#trends of DUI arrests over the week, year, or days for a certain area 

#split data by area name (each dataframe corresponding to an area name)
#select charge description column and display # of unique charge description values for the area name

arrest_area = arrest_datac.groupby("Area Name")["Charge Group Description"].value_counts() / arrest_datac.shape[0] * 100

#add this line to get all rows to show up in dataframe 
pd.set_option('display.max_rows', None)

#convert arrest by area panda series to 
df = pd.DataFrame(arrest_area)
df

#next list top 10 charge descriptions for each area
# Out:
#                                             Charge Group Description
# Area Name   Charge Group Description
# 77th Street Miscellaneous Other Violations                  0.793638
#             Narcotic Drug Laws                              0.613868
#             Aggravated Assault                              0.595928
#             Driving Under Influence                         0.532574
#             Prostitution/Allied                             0.425393
#             Moving Traffic Violations                       0.380810
#             Other Assaults                                  0.366882
#             Weapon (carry/poss)                             0.299289
#             Robbery                                         0.224807
#             Larceny                                         0.223672
#             Vehicle Theft                                   0.208079
#             Burglary                                        0.156684
#             Drunkeness                                      0.148055
#             Sex (except rape/prst)                          0.083262
#             Non-Criminal Detention                          0.051925
#             Against Family/Child                            0.050865
#             Fraud/Embezzlement                              0.043069
#             Receive Stolen Property                         0.038906
#             Forgery/Counterfeit                             0.030201
#             Homicide                                        0.028158
#             Pre-Delinquency                                 0.025206
#             Rape                                            0.023162
#             Disorderly Conduct                              0.017258
#             Liquor Laws                                     0.015063
#             Gambling                                        0.007645
#             Disturbing the Peace                            0.004542
#             Federal Offenses                                0.001665
# Central     Miscellaneous Other Violations                  2.183733
#             Narcotic Drug Laws                              1.846447
#             Disorderly Conduct                              1.500607
#             Drunkeness                                      0.839507
#             Liquor Laws                                     0.545895
#             Other Assaults                                  0.424939
#             Larceny                                         0.399733
#             Driving Under Influence                         0.392391
#             Aggravated Assault                              0.369002
#             Moving Traffic Violations                       0.244941
#             Robbery                                         0.133749
#             Sex (except rape/prst)                          0.100368
#             Weapon (carry/poss)                             0.089317
#             Burglary                                        0.086138
#             Fraud/Embezzlement                              0.065626
#             Vehicle Theft                                   0.064339
#             Prostitution/Allied                             0.063203
#             Forgery/Counterfeit                             0.056542
#             Receive Stolen Property                         0.018318
#             Rape                                            0.016350
#             Disturbing the Peace                            0.015820
#             Gambling                                        0.013095
#             Against Family/Child                            0.012943
#             Non-Criminal Detention                          0.011581
#             Homicide                                        0.011354
#             Pre-Delinquency                                 0.006207
#             Federal Offenses                                0.001362
# Devonshire  Miscellaneous Other Violations                  0.541808
#             Larceny                                         0.512666
#             Narcotic Drug Laws                              0.396327
#             Driving Under Influence                         0.331231
#             Drunkeness                                      0.197936
#             Aggravated Assault                              0.176061
#             Other Assaults                                  0.148206
#             Moving Traffic Violations                       0.143967
#             Burglary                                        0.067594
#             Pre-Delinquency                                 0.057375
#             Weapon (carry/poss)                             0.054726
#             Vehicle Theft                                   0.051168
#             Robbery                                         0.037922
#             Fraud/Embezzlement                              0.035727
#             Liquor Laws                                     0.032094
#             Disturbing the Peace                            0.022859
#             Disorderly Conduct                              0.021724
#             Against Family/Child                            0.020286
#             Prostitution/Allied                             0.020210
#             Sex (except rape/prst)                          0.020134
#             Forgery/Counterfeit                             0.019377
#             Receive Stolen Property                         0.016804
#             Non-Criminal Detention                          0.016123
#             Rape                                            0.008932
#             Gambling                                        0.008326
#             Homicide                                        0.003179
#             Federal Offenses                                0.000378
# Foothill    Narcotic Drug Laws                              0.611445
#             Miscellaneous Other Violations                  0.582531
#             Driving Under Influence                         0.478756
#             Aggravated Assault                              0.265227
#             Drunkeness                                      0.202781
#             Moving Traffic Violations                       0.187945
#             Other Assaults                                  0.182798
#             Prostitution/Allied                             0.159182
#             Larceny                                         0.144119
#             Vehicle Theft                                   0.121714
#             Weapon (carry/poss)                             0.121033
#             Liquor Laws                                     0.097795
#             Burglary                                        0.075844
#             Robbery                                         0.055331
#             Non-Criminal Detention                          0.040496
#             Against Family/Child                            0.031261
#             Sex (except rape/prst)                          0.030201
#             Fraud/Embezzlement                              0.028839
#             Receive Stolen Property                         0.026720
#             Pre-Delinquency                                 0.018015
#             Disturbing the Peace                            0.016501
#             Forgery/Counterfeit                             0.016047
#             Disorderly Conduct                              0.011203
#             Rape                                            0.008629
#             Homicide                                        0.006131
#             Gambling                                        0.004693
#             Federal Offenses                                0.000833
# Harbor      Miscellaneous Other Violations                  0.746935
#             Narcotic Drug Laws                              0.565954
#             Drunkeness                                      0.316168
#             Aggravated Assault                              0.302014
#             Driving Under Influence                         0.226245
#             Other Assaults                                  0.216859
#             Larceny                                         0.187642
#             Liquor Laws                                     0.137534
#             Moving Traffic Violations                       0.127012
#             Weapon (carry/poss)                             0.118989
#             Vehicle Theft                                   0.088787
#             Burglary                                        0.086214
#             Pre-Delinquency                                 0.073498
#             Robbery                                         0.064187
#             Disorderly Conduct                              0.057451
#             Prostitution/Allied                             0.046475
#             Sex (except rape/prst)                          0.039663
#             Against Family/Child                            0.032245
#             Receive Stolen Property                         0.031488
#             Non-Criminal Detention                          0.023540
#             Forgery/Counterfeit                             0.019756
#             Fraud/Embezzlement                              0.016123
#             Disturbing the Peace                            0.009840
#             Gambling                                        0.009310
#             Rape                                            0.008023
#             Homicide                                        0.007721
#             Federal Offenses                                0.000606
# Hollenbeck  Miscellaneous Other Violations                  0.614246
#             Drunkeness                                      0.376344
#             Narcotic Drug Laws                              0.335016
#             Driving Under Influence                         0.289373
#             Aggravated Assault                              0.278927
#             Liquor Laws                                     0.248575
#             Other Assaults                                  0.173790
#             Weapon (carry/poss)                             0.127542
#             Moving Traffic Violations                       0.118837
#             Vehicle Theft                                   0.095297
#             Larceny                                         0.093783
#             Robbery                                         0.064187
#             Burglary                                        0.057754
#             Against Family/Child                            0.042085
#             Non-Criminal Detention                          0.031791
#             Pre-Delinquency                                 0.030353
#             Sex (except rape/prst)                          0.027628
#             Receive Stolen Property                         0.022935
#             Rape                                            0.011808
#             Disorderly Conduct                              0.010143
#             Fraud/Embezzlement                              0.008856
#             Homicide                                        0.008553
#             Prostitution/Allied                             0.008402
#             Gambling                                        0.007645
#             Forgery/Counterfeit                             0.007266
#             Disturbing the Peace                            0.007039
#             Federal Offenses                                0.000833
# Hollywood   Miscellaneous Other Violations                  1.732529
#             Drunkeness                                      1.244690
#             Narcotic Drug Laws                              1.006031
#             Liquor Laws                                     0.733235
#             Driving Under Influence                         0.727634
#             Prostitution/Allied                             0.516527
#             Disorderly Conduct                              0.432508
#             Other Assaults                                  0.342736
#             Aggravated Assault                              0.315184
#             Larceny                                         0.252208
#             Moving Traffic Violations                       0.244109
#             Robbery                                         0.128223
#             Weapon (carry/poss)                             0.120881
#             Sex (except rape/prst)                          0.088636
#             Burglary                                        0.088333
#             Vehicle Theft                                   0.078266
#             Fraud/Embezzlement                              0.073952
#             Receive Stolen Property                         0.037468
#             Forgery/Counterfeit                             0.032018
#             Against Family/Child                            0.017409
#             Disturbing the Peace                            0.017334
#             Non-Criminal Detention                          0.013776
#             Gambling                                        0.013473
#             Rape                                            0.012716
#             Homicide                                        0.005677
#             Pre-Delinquency                                 0.004617
#             Federal Offenses                                0.000908
# Mission     Miscellaneous Other Violations                  1.058789
#             Narcotic Drug Laws                              0.734824
#             Driving Under Influence                         0.482616
#             Aggravated Assault                              0.359843
#             Larceny                                         0.277943
#             Drunkeness                                      0.267422
#             Other Assaults                                  0.237751
#             Moving Traffic Violations                       0.167432
#             Liquor Laws                                     0.157441
#             Vehicle Theft                                   0.134430
#             Prostitution/Allied                             0.131857
#             Weapon (carry/poss)                             0.115583
#             Burglary                                        0.103245
#             Robbery                                         0.091740
#             Pre-Delinquency                                 0.083943
#             Disorderly Conduct                              0.053969
#             Fraud/Embezzlement                              0.044583
#             Sex (except rape/prst)                          0.036257
#             Against Family/Child                            0.034592
#             Non-Criminal Detention                          0.034516
#             Receive Stolen Property                         0.028839
#             Forgery/Counterfeit                             0.027476
#             Disturbing the Peace                            0.027174
#             Gambling                                        0.013246
#             Homicide                                        0.011430
#             Rape                                            0.010143
#             Federal Offenses                                0.000757
# N Hollywood Driving Under Influence                         0.933366
#             Miscellaneous Other Violations                  0.868952
#             Narcotic Drug Laws                              0.575718
#             Larceny                                         0.290130
#             Aggravated Assault                              0.279155
#             Drunkeness                                      0.241081
#             Other Assaults                                  0.208458
#             Moving Traffic Violations                       0.193092
#             Fraud/Embezzlement                              0.138972
#             Liquor Laws                                     0.131932
#             Burglary                                        0.100141
#             Vehicle Theft                                   0.085533
#             Prostitution/Allied                             0.077661
#             Weapon (carry/poss)                             0.077585
#             Robbery                                         0.065247
#             Pre-Delinquency                                 0.062901
#             Disorderly Conduct                              0.052077
#             Sex (except rape/prst)                          0.040041
#             Receive Stolen Property                         0.029747
#             Against Family/Child                            0.027779
#             Forgery/Counterfeit                             0.026871
#             Non-Criminal Detention                          0.016652
#             Disturbing the Peace                            0.014306
#             Rape                                            0.010446
#             Gambling                                        0.009007
#             Homicide                                        0.005374
#             Federal Offenses                                0.000908
# Newton      Miscellaneous Other Violations                  1.136525
#             Narcotic Drug Laws                              0.664355
#             Drunkeness                                      0.619620
#             Driving Under Influence                         0.467629
#             Aggravated Assault                              0.407454
#             Moving Traffic Violations                       0.241989
#             Other Assaults                                  0.224202
#             Liquor Laws                                     0.198769
#             Weapon (carry/poss)                             0.194454
#             Disorderly Conduct                              0.155700
#             Robbery                                         0.149342
#             Vehicle Theft                                   0.145179
#             Burglary                                        0.107332
#             Prostitution/Allied                             0.106878
#             Larceny                                         0.094237
#             Sex (except rape/prst)                          0.049957
#             Non-Criminal Detention                          0.041480
#             Receive Stolen Property                         0.033532
#             Against Family/Child                            0.032851
#             Forgery/Counterfeit                             0.027779
#             Pre-Delinquency                                 0.020664
#             Homicide                                        0.018393
#             Gambling                                        0.017334
#             Fraud/Embezzlement                              0.014457
#             Disturbing the Peace                            0.011732
#             Rape                                            0.009991
#             Federal Offenses                                0.001741
# Northeast   Drunkeness                                      0.797271
#             Miscellaneous Other Violations                  0.667836
#             Narcotic Drug Laws                              0.475728
#             Driving Under Influence                         0.323662
#             Larceny                                         0.252586
#             Aggravated Assault                              0.240551
#             Other Assaults                                  0.192411
#             Moving Traffic Violations                       0.135717
#             Liquor Laws                                     0.117853
#             Vehicle Theft                                   0.087576
#             Weapon (carry/poss)                             0.080386
#             Burglary                                        0.075768
#             Robbery                                         0.063809
#             Sex (except rape/prst)                          0.039587
#             Pre-Delinquency                                 0.034592
#             Against Family/Child                            0.032851
#             Disorderly Conduct                              0.025433
#             Prostitution/Allied                             0.016955
#             Fraud/Embezzlement                              0.015441
#             Receive Stolen Property                         0.015441
#             Non-Criminal Detention                          0.014382
#             Forgery/Counterfeit                             0.013776
#             Disturbing the Peace                            0.010294
#             Rape                                            0.008326
#             Homicide                                        0.005071
#             Gambling                                        0.003860
#             Federal Offenses                                0.000681
# Olympic     Miscellaneous Other Violations                  0.790080
#             Drunkeness                                      0.533558
#             Driving Under Influence                         0.398295
#             Aggravated Assault                              0.350911
#             Narcotic Drug Laws                              0.345234
#             Prostitution/Allied                             0.237221
#             Other Assaults                                  0.222688
#             Moving Traffic Violations                       0.163269
#             Larceny                                         0.130646
#             Robbery                                         0.105061
#             Weapon (carry/poss)                             0.080764
#             Burglary                                        0.073422
#             Pre-Delinquency                                 0.072514
#             Vehicle Theft                                   0.070167
#             Liquor Laws                                     0.056467
#             Sex (except rape/prst)                          0.051849
#             Fraud/Embezzlement                              0.028385
#             Non-Criminal Detention                          0.027704
#             Forgery/Counterfeit                             0.022708
#             Against Family/Child                            0.018545
#             Receive Stolen Property                         0.018545
#             Gambling                                        0.018242
#             Disorderly Conduct                              0.013852
#             Rape                                            0.009689
#             Homicide                                        0.008553
#             Disturbing the Peace                            0.005374
#             Federal Offenses                                0.000454
# Pacific     Miscellaneous Other Violations                  1.931828
#             Liquor Laws                                     0.678585
#             Narcotic Drug Laws                              0.585407
#             Driving Under Influence                         0.564440
#             Drunkeness                                      0.454610
#             Other Assaults                                  0.253419
#             Aggravated Assault                              0.246380
#             Moving Traffic Violations                       0.212091
#             Larceny                                         0.211183
#             Disorderly Conduct                              0.192638
#             Weapon (carry/poss)                             0.117929
#             Burglary                                        0.096735
#             Prostitution/Allied                             0.084095
#             Robbery                                         0.067821
#             Fraud/Embezzlement                              0.065550
#             Vehicle Theft                                   0.061765
#             Pre-Delinquency                                 0.038755
#             Sex (except rape/prst)                          0.032094
#             Forgery/Counterfeit                             0.029974
#             Receive Stolen Property                         0.024827
#             Against Family/Child                            0.019529
#             Disturbing the Peace                            0.012868
#             Non-Criminal Detention                          0.009689
#             Rape                                            0.009462
#             Homicide                                        0.006131
#             Gambling                                        0.002801
#             Federal Offenses                                0.002498
# Rampart     Miscellaneous Other Violations                  1.080891
#             Drunkeness                                      0.689863
#             Narcotic Drug Laws                              0.523036
#             Aggravated Assault                              0.409422
#             Driving Under Influence                         0.366277
#             Other Assaults                                  0.254327
#             Liquor Laws                                     0.232604
#             Larceny                                         0.145481
#             Robbery                                         0.144951
#             Weapon (carry/poss)                             0.103926
#             Moving Traffic Violations                       0.103018
#             Prostitution/Allied                             0.092194
#             Vehicle Theft                                   0.075314
#             Burglary                                        0.073422
#             Pre-Delinquency                                 0.054801
#             Sex (except rape/prst)                          0.050790
#             Disorderly Conduct                              0.039360
#             Non-Criminal Detention                          0.031185
#             Forgery/Counterfeit                             0.027779
#             Gambling                                        0.026492
#             Receive Stolen Property                         0.025357
#             Against Family/Child                            0.023465
#             Fraud/Embezzlement                              0.019983
#             Rape                                            0.015895
#             Homicide                                        0.009310
#             Disturbing the Peace                            0.009159
#             Federal Offenses                                0.000378
# Southeast   Miscellaneous Other Violations                  0.551270
#             Narcotic Drug Laws                              0.491397
#             Aggravated Assault                              0.413358
#             Driving Under Influence                         0.318590
#             Other Assaults                                  0.242292
#             Prostitution/Allied                             0.238659
#             Weapon (carry/poss)                             0.229727
#             Moving Traffic Violations                       0.208155
#             Robbery                                         0.168568
#             Vehicle Theft                                   0.136852
#             Drunkeness                                      0.118459
#             Burglary                                        0.111874
#             Pre-Delinquency                                 0.098325
#             Larceny                                         0.091058
#             Sex (except rape/prst)                          0.049957
#             Non-Criminal Detention                          0.049881
#             Disorderly Conduct                              0.045794
#             Against Family/Child                            0.030504
#             Receive Stolen Property                         0.026947
#             Liquor Laws                                     0.018393
#             Fraud/Embezzlement                              0.017409
#             Homicide                                        0.016047
#             Forgery/Counterfeit                             0.012035
#             Rape                                            0.008780
#             Disturbing the Peace                            0.002195
#             Gambling                                        0.002119
#             Federal Offenses                                0.000757
# Southwest   Miscellaneous Other Violations                  0.808852
#             Narcotic Drug Laws                              0.598048
#             Drunkeness                                      0.551800
#             Larceny                                         0.492229
#             Aggravated Assault                              0.470430
#             Driving Under Influence                         0.410708
#             Other Assaults                                  0.322451
#             Moving Traffic Violations                       0.270828
#             Prostitution/Allied                             0.213756
#             Robbery                                         0.189307
#             Weapon (carry/poss)                             0.152899
#             Vehicle Theft                                   0.134884
#             Burglary                                        0.127088
#             Sex (except rape/prst)                          0.098855
#             Liquor Laws                                     0.068805
#             Disorderly Conduct                              0.053742
#             Non-Criminal Detention                          0.039284
#             Against Family/Child                            0.035273
#             Receive Stolen Property                         0.033305
#             Fraud/Embezzlement                              0.029142
#             Forgery/Counterfeit                             0.028158
#             Pre-Delinquency                                 0.018847
#             Rape                                            0.013473
#             Homicide                                        0.012111
#             Disturbing the Peace                            0.005904
#             Gambling                                        0.003179
#             Federal Offenses                                0.001892
# Topanga     Narcotic Drug Laws                              0.543549
#             Larceny                                         0.541203
#             Miscellaneous Other Violations                  0.536888
#             Driving Under Influence                         0.299289
#             Aggravated Assault                              0.223369
#             Drunkeness                                      0.193395
#             Other Assaults                                  0.156457
#             Moving Traffic Violations                       0.112404
#             Liquor Laws                                     0.093935
#             Burglary                                        0.082354
#             Prostitution/Allied                             0.062219
#             Vehicle Theft                                   0.061690
#             Pre-Delinquency                                 0.057905
#             Weapon (carry/poss)                             0.056391
#             Robbery                                         0.052455
#             Fraud/Embezzlement                              0.049352
#             Forgery/Counterfeit                             0.030277
#             Against Family/Child                            0.022708
#             Sex (except rape/prst)                          0.022556
#             Receive Stolen Property                         0.019907
#             Disorderly Conduct                              0.017788
#             Non-Criminal Detention                          0.017334
#             Disturbing the Peace                            0.013700
#             Rape                                            0.007115
#             Gambling                                        0.006358
#             Homicide                                        0.002952
#             Federal Offenses                                0.000606
# Van Nuys    Miscellaneous Other Violations                  0.789550
#             Driving Under Influence                         0.665641
#             Narcotic Drug Laws                              0.602741
#             Prostitution/Allied                             0.515997
#             Moving Traffic Violations                       0.472247
#             Larceny                                         0.396024
#             Aggravated Assault                              0.328203
#             Liquor Laws                                     0.247591
#             Other Assaults                                  0.240097
#             Drunkeness                                      0.154035
#             Burglary                                        0.092345
#             Weapon (carry/poss)                             0.077055
#             Sex (except rape/prst)                          0.074860
#             Fraud/Embezzlement                              0.071605
#             Vehicle Theft                                   0.070924
#             Robbery                                         0.068123
#             Forgery/Counterfeit                             0.035046
#             Pre-Delinquency                                 0.033986
#             Against Family/Child                            0.031261
#             Disorderly Conduct                              0.028082
#             Non-Criminal Detention                          0.019226
#             Receive Stolen Property                         0.018620
#             Disturbing the Peace                            0.012035
#             Homicide                                        0.011278
#             Rape                                            0.010597
#             Gambling                                        0.005223
#             Federal Offenses                                0.000833
# West LA     Drunkeness                                      0.457941
#             Miscellaneous Other Violations                  0.358102
#             Driving Under Influence                         0.231998
#             Narcotic Drug Laws                              0.230333
#             Larceny                                         0.158955
#             Aggravated Assault                              0.118005
#             Other Assaults                                  0.109452
#             Disorderly Conduct                              0.071605
#             Liquor Laws                                     0.063733
#             Moving Traffic Violations                       0.062219
#             Burglary                                        0.050865
#             Robbery                                         0.027855
#             Fraud/Embezzlement                              0.025736
#             Weapon (carry/poss)                             0.022329
#             Vehicle Theft                                   0.021270
#             Prostitution/Allied                             0.019150
#             Sex (except rape/prst)                          0.016198
#             Forgery/Counterfeit                             0.013625
#             Against Family/Child                            0.009991
#             Disturbing the Peace                            0.006964
#             Pre-Delinquency                                 0.006812
#             Receive Stolen Property                         0.006282
#             Rape                                            0.005677
#             Non-Criminal Detention                          0.004844
#             Gambling                                        0.003406
#             Homicide                                        0.001590
#             Federal Offenses                                0.000076
# West Valley Miscellaneous Other Violations                  0.514029
#             Driving Under Influence                         0.489807
#             Narcotic Drug Laws                              0.468992
#             Aggravated Assault                              0.210047
#             Drunkeness                                      0.202326
#             Moving Traffic Violations                       0.162058
#             Other Assaults                                  0.151688
#             Larceny                                         0.149190
#             Vehicle Theft                                   0.078645
#             Weapon (carry/poss)                             0.074936
#             Burglary                                        0.068048
#             Pre-Delinquency                                 0.065777
#             Robbery                                         0.047157
#             Fraud/Embezzlement                              0.046778
#             Liquor Laws                                     0.040647
#             Forgery/Counterfeit                             0.033532
#             Prostitution/Allied                             0.031261
#             Sex (except rape/prst)                          0.028612
#             Against Family/Child                            0.022027
#             Receive Stolen Property                         0.021724
#             Disorderly Conduct                              0.013322
#             Non-Criminal Detention                          0.012414
#             Gambling                                        0.009840
#             Disturbing the Peace                            0.008780
#             Rape                                            0.008023
#             Homicide                                        0.004844
#             Federal Offenses                                0.000303
# Wilshire    Miscellaneous Other Violations                  0.430464
#             Narcotic Drug Laws                              0.269920
#             Driving Under Influence                         0.268255
#             Larceny                                         0.257506
#             Aggravated Assault                              0.204067
#             Drunkeness                                      0.187869
#             Other Assaults                                  0.139880
#             Moving Traffic Violations                       0.111117
#             Robbery                                         0.067291
#             Burglary                                        0.064793
#             Liquor Laws                                     0.055634
#             Weapon (carry/poss)                             0.047989
#             Vehicle Theft                                   0.041177
#             Pre-Delinquency                                 0.035424
#             Sex (except rape/prst)                          0.034970
#             Fraud/Embezzlement                              0.026568
#             Prostitution/Allied                             0.021043
#             Forgery/Counterfeit                             0.019302
#             Against Family/Child                            0.015971
#             Disorderly Conduct                              0.015668
#             Non-Criminal Detention                          0.015063
#             Receive Stolen Property                         0.013398
#             Rape                                            0.009991
#             Gambling                                        0.004012
#             Disturbing the Peace                            0.003936
#             Homicide                                        0.003406
#             Federal Offenses                                0.000303

# %%
dui_data.head()
# Out:
#       Report ID Report Type Arrest Date    Time  Area ID  Area Name  \
# 948   150326444         RFC  12/12/2015  2000.0        3  Southwest
# 973   151817927         RFC  09/25/2015  2020.0       18  Southeast
# 1131  162106165         RFC  02/19/2016  2220.0       21    Topanga
# 4297  100601250         RFC  11/01/2010   215.0        6  Hollywood
# 4307  100601358         RFC  12/18/2010   140.0        6  Hollywood
#
#       Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 948                  361   19        M            B               22.0
# 973                 1801   41        F            B               22.0
# 1131                2105   40        M            W               22.0
# 4297                 636   22        F            O               22.0
# 4307                 645   26        M            W               22.0
#
#      Charge Group Description Arrest Type Code      Charge  \
# 948   Driving Under Influence                M  23152(E)VC
# 973   Driving Under Influence                M  23152(E)VC
# 1131  Driving Under Influence                M  23152(E)VC
# 4297  Driving Under Influence                M  23152(A)VC
# 4307  Driving Under Influence                M  23152(A)VC
#
#                      Charge Description      Disposition Description  \
# 948   DUI .04 OR MORE BAC PASS FOR HIRE  MISDEMEANOR COMPLAINT FILED
# 973   DUI .04 OR MORE BAC PASS FOR HIRE  MISDEMEANOR COMPLAINT FILED
# 1131  DUI .04 OR MORE BAC PASS FOR HIRE  MISDEMEANOR COMPLAINT FILED
# 4297        DRUNK DRIVING ALCOHOL/DRUGS  MISDEMEANOR COMPLAINT FILED
# 4307        DRUNK DRIVING ALCOHOL/DRUGS  MISDEMEANOR COMPLAINT FILED
#
#                               Address                     Cross Street  \
# 948                           LA BREA                            RODEO
# 973                        MANCHESTER                           HOOVER
# 1131  CANOGA                       AV  CHASE                        ST
# 4297  CAHUENGA                     BL  HOLLYWOOD                    BL
# 4307  HOLLYWOOD                    BL  HIGHLAND                     AV
#
#           LAT       LON                   Location Booking Date  Booking Time  \
# 948   34.0183 -118.3556  POINT (-118.3556 34.0183)          NaN           NaN
# 973   33.9601 -118.2881  POINT (-118.2881 33.9601)          NaN           NaN
# 1131  34.2246 -118.5976  POINT (-118.5976 34.2246)          NaN           NaN
# 4297  34.1016 -118.3297  POINT (-118.3297 34.1016)          NaN           NaN
# 4307  34.1016 -118.3387  POINT (-118.3387 34.1016)          NaN           NaN
#
#      Booking Location  Booking Location Code
# 948               NaN                    NaN
# 973               NaN                    NaN
# 1131              NaN                    NaN
# 4297              NaN                    NaN
# 4307              NaN                    NaN

# %%
#use only dui data 

#goal: calculate the proportion of DUI arrests (out of total # arrests for each area)

#for each charge description in each area, count the number of rows 
#dui_data dataframe contains just DUI arrests for all areas 

dui_datac = dui_datac.groupby('Area Name')['Charge Description'].count().reset_index(name = 'count')
#counting each type of charge description for each area 
#.reset_index() turns that into a new dataframe and name the aggregate "count" 
#go to this column called count --> 

dui_datac
# Out:
#       Area Name  count
# 0   77th Street   7036
# 1       Central   5184
# 2    Devonshire   4376
# 3      Foothill   6325
# 4        Harbor   2989
# 5    Hollenbeck   3823
# 6     Hollywood   9613
# 7       Mission   6376
# 8   N Hollywood  12331
# 9        Newton   6178
# 10    Northeast   4276
# 11      Olympic   5262
# 12      Pacific   7457
# 13      Rampart   4839
# 14    Southeast   4209
# 15    Southwest   5426
# 16      Topanga   3954
# 17     Van Nuys   8794
# 18      West LA   3065
# 19  West Valley   6471
# 20     Wilshire   3544

# %%
dui_datac.loc[dui_datac['Area Name'] == "Southwest"].iloc[0, 1]
#go into dui_datac and locating all the counts of southwest under area name 
#iloc can take in index , loc can take in column names/strings
#locating row 0, column 1 and pulls out that value
# Out:
# 5426

# %%
DUI_ratio = {"Area Name": [], "DUI Ratio": []} #create a dictionary of DUI ratios and area name
#create key that corresponds to column name, and value that corresponds to the other column name

for area in dui_datac['Area Name'].unique(): #iterating through each unique area, calculate the ratio of DUI arrests to total arrests in the area 
    dict_ratio = (dui_datac.loc[dui_datac['Area Name'] == area].iloc[0, 1]) / len(arrest_datac[arrest_datac['Area Name'] == area]) #What is this line doing??? 
    #taking count of the area --> iloc[1] pulls out the data and divide by total 
    DUI_ratio["Area Name"].append(area) #go to the key area name and append the key's values --- value for that key is a list of values
    DUI_ratio["DUI Ratio"].append(dict_ratio) #
    
    #key: area name, value: the corresponding proportion of DUI arrests for that area

# %%
DUI_ratiodf = pd.DataFrame.from_dict(DUI_ratio) #create dataframe from a dictionary
DUI_ratiodf

# %%
#To create a df of Ratios for each type of charge description (for later)
 
#the put the for loop into a function
#anywhere where it says DUI --> input the type of charge
#nest all of that for loop within another for loop that loops through all types of charges 

#create an empty dataframe at the very start and loop it through each type of charge --> loop through each area and create individual charge dataframe 
#and merge into an empty dataframe

# %%
#sort DUI_ratiodf by DUI Ratio (in decreasing order for DUI ratio from all years) 

#Among all areas, N Hollywood, West Valley, Foothill, Van Nuys, Wilshire, Devonshire, West La, and Olympic had > 10% of arrests being DUI arrests over the years 
#N. Hollywood had a exceptionally high DUI ratio of almost 20% of all arrests being DUI arrests, I wonder what the trend for DUI arrests looks like over the years (e.g.
#has it been decreasing? Or staying about the same?)
#What is the DUI arrest trend like for other areas? 

DUI_ratiodf.sort_values("DUI Ratio", ascending = False)

# %%
#reset dui_datac to include all the other columns
dui_datac = clean_data(dui_data)
dui_datac.head()

# %%
#line graph 
#1) trends of num of DUI arrests against year for North Hollywood area 
#2) trends of DUI arrests against year for all the other areas 
#3) map plot and plot arrests for each area on a map 
    #have a slider to slide along years --> arrests pop up for one area

#convert Arrest date column to a dt attribute so dates show up as Year - month - day
dui_datac["Arrest Date"] = pd.to_datetime(dui_datac["Arrest Date"])

#extract year from Arrest Date --> add a column to dui_datac df of year of arrest 
dui_datac["Arrest Year"] = dui_datac["Arrest Date"].dt.year
 
#make a dataframe consisting of dui arrest data grouped by area name and arrest year 

#NEXT STEP: put this in graph form but not completely sure how to do that
duiyear = dui_datac.groupby(["Area Name", "Arrest Year"]).size().reset_index(name = "Count")
duiyear.head()

# %%
#duiyear.plot(kind = "barh")
dict = {}

#putting area names into a dictionary
#enumerate gives you a list of tuples
for count, name in enumerate(duiyear['Area Name'].unique()):
    dict[count] = name #originally: dict[count+1] = name
    
dict

# %%
from matplotlib import pyplot as plt

#graphing num of dui arrests against year for each area name to see trend of dui arrests 
#not sure how to set title for each graph, the x and y axis 

def line_graph(df):
    
    nrows = 3
    ncols = 7
    fig, ax = plt.subplots(nrows, ncols, figsize = (25, 5), sharey = True)
    count = 0
    
    #ax[0].set(yaxis = "Year") #set_ylabel, or set_xlabel 
    
    for row in np.arange(0, nrows): #iterate through each row
        for col in np.arange(0, ncols): #iterate through each col
            area_df = df[df["Area Name"] == dict[count]] #extract data for the specific area name and set to new data frame
            ax[row][col].plot(area_df["Arrest Year"], area_df["Count"])
            ax[row][col].set_title(dict[count])
            ax[row][col].set_xlabel("Year")
            ax[row][col].set_ylabel("Number of Arrests")
            count+=1
    
    #fig.text(0.5, 0.005, 'Year', ha='center', va='center', fontsize = 12)
    #plt.ylabel("Number of Arrests")
    #fig.text(0.001, 0.5, 'Number of Arrests', ha='center', va='center', fontsize = 12, rotation = "vertical") #the lower the x, closer to left; the lower the y, closer to bottom

    fig.tight_layout()
            
line_graph(duiyear)

#note anomolies, some trends that are consistently flat, similar trends,  
#any overall increasing, decreasing trend 
#at which year, dui arrests peaked 
#recommendations on what else to explore --> 

#to show which regions have worse DUI arrests --> make recs on allocation of resources 
#table of values
#count per year for each region to compare 
#2011-2015 sum of that against 2016-2019 (for each region)

#for cleaning: any outliers in latitude, longtitude
#can jump right into making the map to see outliers

#streamlit to deploy the map as standalone website, folium to plot for interactive map

# %%
county = gpd.read_file("/Users/anniechen/Downloads/tl_2018_06037_roads")
fig, ax = plt.subplots(figsize = (15, 15))
county.plot(ax = ax)

# %%
dui_datac.head()

# %%
#point objects (from latitude and longtitude) are already created in the dataframe
#now proceed to plot the points onto the map (for one year 2019)

#making the Location column --
geometry = [Point(xy) for xy in zip( dui_data["LAT"], dui_datac["LON"])] 

geo_df = gpd.GeoDataFrame(dui_datac, crs = "EPSG:4326", geometry = geometry)
geo_df.head()

# %%
#plotting a map of where most dui arrests are occurring starting for a specific year (2019)
fig, ax = plt.subplots(figsize = (15, 15))
county.plot(ax = ax, alpha = 0.4, color = "grey")
geo_df = geo_df[geo_df["Arrest Year"] == "2019"]

geo_df.plot(ax = ax, markersize = 20, color = "blue", column = "Location")

#plt.legend(prop = {"size": 15})

# %%
#get latitudes and longtitudes as columns
fig, ax = plt.subplots(figsize = (15, 15))
county.plot(ax = ax, alpha = 0.4, color = "grey")

dui_datac = dui_datac[(dui_datac["LON"] < -100) & (dui_datac["LAT"] > 30)]

#converts raw LAT and LON into geopandas coordinate system (same as list comprehension above)
data_points = gpd.GeoDataFrame(dui_datac, geometry=gpd.points_from_xy(dui_datac.LON, dui_datac.LAT))

#plot where you intend to plot 
data_points.plot(ax = ax)

#filter out longtitudes < -100, latitude > 30 --> keep 


#plt.hist(geo_df.loc[:, "LAT"].values)

# %%
#Scratch work
#dui_data['Area Name'].unique #extract the values in area name column and output the unique area names

# %%
#Scratch work
#for area in dui_data['Area Name'].unique:
   # dui_data['Area Name'] == area

# %%
#Scratch work 
#visualizations -- show distribution of variables of interest 
#variables of interest 
#plotting one of variables in arrest data against time

#how would I go about doin gthat
#plotting number of dui arrests for each region against time
#plotting number of dui arrests collectively against time --> see if there are any anomolies there
